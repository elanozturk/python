# %% [markdown]
# <a href="https://colab.research.google.com/github/elanozturk/python/blob/main/Ders_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#KAGGLE

# %%
import numpy as np
import pandas as pd

# %%
lego = pd.read_csv("sets.csv")

# %%
lego.info() #dataframe genel bilgileri
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14936 entries, 0 to 14935
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Set_ID            14936 non-null  object
#  1   Name              14936 non-null  object
#  2   Year              14936 non-null  int64
#  3   Theme             14936 non-null  object
#  4   Theme_Group       14915 non-null  object
#  5   Subtheme          11495 non-null  object
#  6   Category          14936 non-null  object
#  7   Packaging         14936 non-null  object
#  8   Num_Instructions  14936 non-null  int64
#  9   Availability      14936 non-null  object
#  10  Pieces            13133 non-null  float64
#  11  Minifigures       7686 non-null   float64
#  12  Owned             14771 non-null  float64
#  13  Rating            14936 non-null  float64
#  14  USD_MSRP          5837 non-null   float64
#  15  Total_Quantity    12276 non-null  float64
# ...

# %%
lego.head(4) İlk 4 Satırı yazdırır.
# Out:
#   Set_ID            Name  Year      Theme Theme_Group Subtheme Category  \
# 0   75-1   PreSchool Set  1975  PreSchool  Pre-school      NaN   Normal
# 1   77-1   PreSchool Set  1975  PreSchool  Pre-school      NaN   Normal
# 2  077-1  Pre-School Set  1975      Duplo  Pre-school      NaN   Normal
# 3   78-1   PreSchool Set  1975  PreSchool  Pre-school      NaN   Normal
#
#          Packaging  Num_Instructions     Availability  Pieces  Minifigures  \
# 0  {Not specified}                 0  {Not specified}    16.0          NaN
# 1  {Not specified}                 0  {Not specified}    20.0          NaN
# 2  {Not specified}                 0  {Not specified}    21.0          NaN
# 3  {Not specified}                 0  {Not specified}    32.0          NaN
#
#    Owned  Rating  USD_MSRP  Total_Quantity  Current_Price
# 0   10.0     0.0       NaN             NaN            NaN
# 1   11.0     0.0       NaN             NaN            NaN
# ...

# %%
lego.tail(6) #son altı
# Out:
#          Set_ID                     Name  Year Theme    Theme_Group  \
# 14930  854241-1  Scarlet Witch Key Chain  2023  Gear  Miscellaneous
# 14931  854242-1        Creeper Key Chain  2023  Gear  Miscellaneous
# 14932  854243-1          Steve Key Chain  2023  Gear  Miscellaneous
# 14933  854244-1         Piglin Key Chain  2023  Gear  Miscellaneous
# 14934  854245-1   Fennec Shand Key Chain  2023  Gear  Miscellaneous
# 14935  854246-1  Scout Trooper Key Chain  2023  Gear  Miscellaneous
#
#                    Subtheme Category Packaging  Num_Instructions  \
# 14930     Key Chains/Marvel     Gear       Tag                 0
# 14931  Key Chains/Minecraft     Gear       Tag                 0
# 14932  Key Chains/Minecraft     Gear       Tag                 0
# 14933  Key Chains/Minecraft     Gear       Tag                 0
# 14934  Key Chains/Star Wars     Gear       Tag                 0
# 14935  Key Chains/Star Wars     Gear       Tag                 0
#
# ...

# %%
lego.sample(8) #rastgele örnek gösterir
# Out:
#          Set_ID                            Name  Year  \
# 7269    66256-1                Bonus/Value Pack  2008
# 12144   41339-1                Mia's Camper Van  2018
# 12796  71024-10                            Anna  2019
# 3033     3312-1                  Paramedic Unit  1998
# 10321   71005-2                    Bart Simpson  2014
# 7999     5867-1                 Super Speedster  2010
# 13032   31102-1                     Fire Dragon  2020
# 7720    66284-1  LEGO Build and Play Value Pack  2009
#
#                          Theme    Theme_Group            Subtheme    Category  \
# 7269                      City     Modern day  Product Collection  Collection
# 12144                  Friends     Modern day      Great Outdoors      Normal
# 12796  Collectable Minifigures  Miscellaneous     Disney Series 2      Normal
# 3033                      Town     Modern day            Football      Normal
# 10321  Collectable Minifigures  Miscellaneous        The Simpsons      Normal
# ...

# %%
ibb = pd.read_excel("rain_baraj.xlsx")

# %%
ibb.sample(10)
# Out:
#           Tarih  Ömerli  Darlik  Elmali  Terkos  B.çekmece  Sazlidere  Alibey  \
# 2448 2017-09-14    0.00    0.00    0.00     0.0       0.00       0.00    0.00
# 2268 2017-03-18   10.33   11.74   10.24     7.3       9.20      11.26   13.41
# 1303 2014-07-27    0.00    0.00    0.00     0.0       0.00       0.00    0.00
# 4446 2023-03-05    1.67    3.40    4.74     0.0       2.05       1.50    1.20
# 3779 2021-05-07    0.80    0.00    0.34     0.2       0.53       0.00    0.40
# 3216 2019-10-22    0.00    0.00    0.00     0.0       0.00       0.00    0.00
# 4673 2023-10-18    5.04    5.80   10.40    12.0       3.49       5.25    4.85
# 113  2011-04-24    0.00    0.00    0.00     0.0       0.00       0.00    0.00
# 4542 2023-06-09    0.00    0.00    0.00     0.0       0.00       0.00    0.00
# 4498 2023-04-26    0.64    1.40    8.96     0.4       0.20       0.48   14.00
#
#       Kazandere  Pabuçdere  ıstırancalar  Unnamed: 11  \
# 2448       0.00       0.00          0.00          NaN
# ...

# %%
starbucks = pd.read_json("https://raw.githubusercontent.com/mmcloughlin/starbucks/master/locations.json")

# %%
starbucks.sample(10)
# Out:
#                city                             name country   longitude  \
# 16849       Shantin                         City One      CN  114.203590
# 5162   Williamsburg  Target Williamsburg East T-2296      US  -76.638100
# 585        Edmonton          Safeway - Edmonton #809      CA -113.518486
# 6190        Altoona            Target-Altoona T-1939      US  -93.503387
# 8428      Milwaukee     Third Ward - 326 North Water      US  -87.908401
# 283        Oakville           2509 Prince Michael Dr      CA  -79.707512
# 10848       Salinas                   Main & Boronda      US -121.655533
# 14542         Seoul                 Artreon Shinchon      KR  126.940239
# 19566           哈尔滨                       哈尔滨远大群力咖啡店      CN  126.557182
# 19335        Mexico               Tlalpan Hospitales      MX  -99.162888
#
#         latitude  store_id
# 16849  22.386311    116540
# 5162   37.258987      7725
# 585    53.547184       890
# 6190   41.643963      8989
# ...

# %%
pd.read_html("https://tr.wikipedia.org/wiki/%C3%9Clkelere_g%C3%B6re_ya%C5%9Fam_kalitesi_s%C4%B1ralamas%C4%B1")
# Out:
# [    Sıra        Ülke    Skor
#  0      1       İsveç  198.57
#  1      2     İsviçre  195.93
#  2      3  Finlandiya  194.01
#  3      4      Norveç  191.13
#  4      5  Avustralya  191.05
#  ..   ...         ...     ...
#  66    67  Filipinler   90.73
#  67    68     Vietnam   88.82
#  68    69  Kazakistan   87.17
#  69    70        İran   87.02
#  70    71       Mısır   83.98
#
#  [71 rows x 3 columns],
#      Sıra Ülke ya da bölge  Skor (10 üzerinden)
#  0      1          İsviçre                 8.22
#  1      2       Avustralya                 8.12
#  2      3           Norveç                 8.09
#  3      4            İsveç                 8.02
#  4      5        Danimarka                 8.01
#  ..   ...              ...                  ...
#  75    76           Angola                 5.09
#  76    77        Bangladeş                 5.07
#  77    78          Ukrayna                 4.98
#  78    79            Kenya                 4.91
# ...

# %%
yasam = pd.read_html("https://tr.wikipedia.org/wiki/%C3%9Clkelere_g%C3%B6re_ya%C5%9Fam_kalitesi_s%C4%B1ralamas%C4%B1")
yasam[0]
# Out:
#     Sıra        Ülke    Skor
# 0      1       İsveç  198.57
# 1      2     İsviçre  195.93
# 2      3  Finlandiya  194.01
# 3      4      Norveç  191.13
# 4      5  Avustralya  191.05
# ..   ...         ...     ...
# 66    67  Filipinler   90.73
# 67    68     Vietnam   88.82
# 68    69  Kazakistan   87.17
# 69    70        İran   87.02
# 70    71       Mısır   83.98
#
# [71 rows x 3 columns]

# %%
yasam1 = yasam[0]

# %%
yasam1.to_excel("yasamendeksi.xlsx")

# %%
pd.read_excel("yasamendeksi.xlsx")
# Out:
#     Unnamed: 0  Sıra        Ülke    Skor
# 0            0     1       İsveç  198.57
# 1            1     2     İsviçre  195.93
# 2            2     3  Finlandiya  194.01
# 3            3     4      Norveç  191.13
# 4            4     5  Avustralya  191.05
# ..         ...   ...         ...     ...
# 66          66    67  Filipinler   90.73
# 67          67    68     Vietnam   88.82
# 68          68    69  Kazakistan   87.17
# 69          69    70        İran   87.02
# 70          70    71       Mısır   83.98
#
# [71 rows x 4 columns]

# %%
starbucks.sample(10)
# Out:
#                 city                             name country   longitude  \
# 21360            北京市                          北京宝钢大厦店      CN  116.446213
# 17379  North Babylon                    North Babylon      US  -73.321022
# 23800       AL KHARJ                           RIYADH      SA   46.680759
# 2983              서울                             방배역점      KR  126.997643
# 16053          Lacey        College & Pacific - Lacey      US -122.822861
# 6233        Campbell                   Hamilton Plaza      US -121.930344
# 20572  San Francisco     Target Express - Bush Street      US -122.401001
# 8230        Stockton     Hwy 99 & Waterloo - Stockton      US -121.244911
# 15909  Boynton Beach  Hypoluxo Road & Congress Avenue      US  -80.089211
# 5695   Santa Barbara  State & Victoria, Santa Barbara      US -119.705757
#
#         latitude  store_id
# 21360  39.907829   1012258
# 17379  40.737572   1005658
# 23800  24.744022   1014922
# 2983   37.482010      4681
# ...

# %%
starbucks.ndim
# Out:
# 2

# %%
starbucks.shape
# Out:
# (25134, 6)

# %%
starbucks["city"]
# Out:
# 0            Hong Kong
# 1            Hong Kong
# 2              Kowloon
# 3            Hong Kong
# 4            Hong Kong
#              ...
# 25129     Independence
# 25130        Middleton
# 25131       Chiang Mai
# 25132           Nantes
# 25133    Overland Park
# Name: city, Length: 25134, dtype: object

# %%
starbucks["country"]
# Out:
# 0        CN
# 1        CN
# 2        CN
# 3        CN
# 4        CN
#          ..
# 25129    US
# 25130    US
# 25131    TH
# 25132    FR
# 25133    US
# Name: country, Length: 25134, dtype: object

# %%
filtre = starbucks["country"] == "TR"
starbucks[filtre]
# Out:
#             city                  name country  longitude   latitude  store_id
# 3796      Ankara             Starbucks      TR  32.860321  39.903343      5911
# 3797    Istanbul             Starbucks      TR  29.125214  40.992905      5912
# 3798    Istanbul             Starbucks      TR  28.988503  41.030354      5913
# 3799    Istanbul             Starbucks      TR  29.123409  40.926819      5914
# 3800      Ankara             Starbucks      TR  32.832993  39.848011      5915
# ...          ...                   ...     ...        ...        ...       ...
# 24911     Ankara          Iran Caddesi      TR  32.862816  39.898464   1015948
# 24926  Eskisehir              Visnelik      TR  30.505999  39.764587   1015846
# 24945   Istanbul  Garanti Zincirlikuyu      TR  29.018337  41.074856   1015653
# 25093   Istanbul     Palladium Reserve      TR  29.100069  40.986504   1015831
# 25102   Istanbul       ACIBADEM NO 190      TR  29.051798  41.010307   1016315
#
# [319 rows x 6 columns]

# %%
filtre1 = starbucks["city"] == "Eskisehir"
filtre2 = starbucks["city"] == "Diyarbakir"
sonuc = starbucks[filtre1 | filtre2]
sonuc
# Out:
#              city                         name country  longitude   latitude  \
# 14682   Eskisehir                    Starbucks      TR  30.509192  39.782043
# 19899  Diyarbakir                    Starbucks      TR  40.206791  37.936352
# 21917   Eskisehir  Acibadem Hospital Eskisehir      TR  30.494699  39.785999
# 23528   Eskisehir                    Starbucks      TR  30.516361  39.777077
# 23857  Diyarbakir                  Ninova Park      TR  39.904110  37.901810
# 24926   Eskisehir                     Visnelik      TR  30.505999  39.764587
#
#        store_id
# 14682     65989
# 19899   1009447
# 21917   1011943
# 23528   1008023
# 23857   1015029
# 24926   1015846

# %%
sonuc.to_excel("star.sonuc.xlsx")

# %%
starbucks["me_lon"] = 29.02373
starbucks["me_lat"] = 40.98914
starbucks
# Out:
#                 city                              name country   longitude  \
# 0          Hong Kong                   Plaza Hollywood      CN  114.201691
# 1          Hong Kong                   Exchange Square      CN  114.158188
# 2            Kowloon                     Telford Plaza      CN  114.213440
# 3          Hong Kong                 Hong Kong Station      CN  114.158463
# 4          Hong Kong            Pacific Place, Central      CN  114.164619
# ...              ...                               ...     ...         ...
# 25129   Independence             E. 39th and Arrowhead      US  -94.360023
# 25130      Middleton                   Allen Boulevard      US  -89.486618
# 25131     Chiang Mai            Chiangmai Ram Hospital      TH   98.977798
# 25132         Nantes                          Beaulieu      FR    1.534722
# 25133  Overland Park  119th & Glenwood - The Fountains      US  -94.661179
#
#         latitude  store_id    me_lon    me_lat
# ...

# %%
starbucks
# Out:
#                 city                              name country   longitude  \
# 0          Hong Kong                   Plaza Hollywood      CN  114.201691
# 1          Hong Kong                   Exchange Square      CN  114.158188
# 2            Kowloon                     Telford Plaza      CN  114.213440
# 3          Hong Kong                 Hong Kong Station      CN  114.158463
# 4          Hong Kong            Pacific Place, Central      CN  114.164619
# ...              ...                               ...     ...         ...
# 25129   Independence             E. 39th and Arrowhead      US  -94.360023
# 25130      Middleton                   Allen Boulevard      US  -89.486618
# 25131     Chiang Mai            Chiangmai Ram Hospital      TH   98.977798
# 25132         Nantes                          Beaulieu      FR    1.534722
# 25133  Overland Park  119th & Glenwood - The Fountains      US  -94.661179
#
#         latitude  store_id    me_lon    me_lat
# ...

# %%
# mesafe_hesabı = ((x1-x2)**2 + (y1-y2) **2)**0.5

# %%
starbucks["mesafe"] = ((starbucks["longitude"]- starbucks["me_lon"])**2 + (starbucks["latitude"] - starbucks["me_lat"])**2)** 0.5

# %%
starbucks
# Out:
#                 city                              name country   longitude  \
# 0          Hong Kong                   Plaza Hollywood      CN  114.201691
# 1          Hong Kong                   Exchange Square      CN  114.158188
# 2            Kowloon                     Telford Plaza      CN  114.213440
# 3          Hong Kong                 Hong Kong Station      CN  114.158463
# 4          Hong Kong            Pacific Place, Central      CN  114.164619
# ...              ...                               ...     ...         ...
# 25129   Independence             E. 39th and Arrowhead      US  -94.360023
# 25130      Middleton                   Allen Boulevard      US  -89.486618
# 25131     Chiang Mai            Chiangmai Ram Hospital      TH   98.977798
# 25132         Nantes                          Beaulieu      FR    1.534722
# 25133  Overland Park  119th & Glenwood - The Fountains      US  -94.661179
#
#         latitude  store_id    me_lon    me_lat      mesafe
# ...

# %%
starbucks["mesafe"] = starbucks["mesafe"] * 100

# %%
starbucks.sort_values(by="mesafe")
# Out:
#                   city                                 name country  \
# 3818          Istanbul                            Starbucks      TR
# 3878   Istanbul - Asya                            Starbucks      TR
# 3860          Istanbul                            Starbucks      TR
# 22547         Istanbul                        Kosuyolu Park      TR
# 3879          Istanbul                            Starbucks      TR
# ...                ...                                  ...     ...
# 5643             Kapaa  Kauai Village Shopping Center Kapaa      US
# 13086            Lihue                  LIH Rotunda (Kauai)      US
# 22502            Lihue                  Safeway-Lihue #2894      US
# 9882             Lihue                   Kukui Grove Center      US
# 4567             Koloa               Poipu Shopping Village      US
#
#         longitude   latitude  store_id    me_lon    me_lat        mesafe
# 3818    29.023399  40.990471      5936  29.02373  40.98914      0.137134
# ...

# %%
starbucks.sort_values(by="mesafe",ascending=False)
# Out:
#                   city                                 name country  \
# 4567             Koloa               Poipu Shopping Village      US
# 9882             Lihue                   Kukui Grove Center      US
# 22502            Lihue                  Safeway-Lihue #2894      US
# 13086            Lihue                  LIH Rotunda (Kauai)      US
# 5643             Kapaa  Kauai Village Shopping Center Kapaa      US
# ...                ...                                  ...     ...
# 3879          Istanbul                            Starbucks      TR
# 22547         Istanbul                        Kosuyolu Park      TR
# 3860          Istanbul                            Starbucks      TR
# 3878   Istanbul - Asya                            Starbucks      TR
# 3818          Istanbul                            Starbucks      TR
#
#         longitude   latitude  store_id    me_lon    me_lat        mesafe
# 4567  -159.458832  21.879017      6981  29.02373  40.98914  18944.886620
# ...

# %%
pd.read_csv("tcl.csv", delimiter=";")
# Out:
#     year         team  played  won  drawn  lost  goals_for  goals_against  \
# 0   1959   Fenerbahce      16   13      2     1         33              8
# 1   1960     Besiktas      38   29      7     2         68             15
# 2   1961   Fenerbahce      38   26      9     3         81             29
# 3   1962  Galatasaray      38   23     11     4         52             18
# 4   1963  Galatasaray      22   14      7     1         54             14
# 5   1964   Fenerbahce      34   21     11     2         55             14
# 6   1965   Fenerbahce      30   18     11     1         52             13
# 7   1966     Besiktas      30   20      8     2         52             16
# 8   1967     Besiktas      32   16     13     3         44             15
# 9   1968   Fenerbahce      32   19     11     2         38             12
# 10  1969  Galatasaray      30   19      8     3         49             14
# 11  1970   Fenerbahce      30   17     10     3         31              6
# ...

# %%
sampi = pd.read_csv("tcl.csv", delimiter=";")
sampi.head(3)
# Out:
#    year        team  played  won  drawn  lost  goals_for  goals_against  \
# 0  1959  Fenerbahce      16   13      2     1         33              8
# 1  1960    Besiktas      38   29      7     2         68             15
# 2  1961  Fenerbahce      38   26      9     3         81             29
#
#    goal_difference  points
# 0               25      28
# 1               53      65
# 2               52      61

# %%
sampi = pd.read_csv("tcl.csv", delimiter=";")
f1 = sampi["points"]>80
sampi[f1]
# Out:
#     year         team  played  won  drawn  lost  goals_for  goals_against  \
# 29  1988  Galatasaray      38   27      9     2         86             35
# 30  1989   Fenerbahce      36   29      6     1        103             27
# 37  1996   Fenerbahce      34   26      6     2         68             19
# 38  1997  Galatasaray      34   25      7     2         90             30
# 44  2003     Besiktas      34   26      7     1         63             21
# 47  2006  Galatasaray      34   26      5     3         82             34
# 52  2011   Fenerbahce      34   26      4     4         84             34
#
#     goal_difference  points
# 29               51      90
# 30               76      93
# 37               49      84
# 38               60      82
# 44               42      85
# 47               48      83
# 52               50      82

# %%
sampi = pd.read_csv("tcl.csv", delimiter=";")
f2 = sampi["lost"] == 0
sampi[f2]
# Out:
#     year      team  played  won  drawn  lost  goals_for  goals_against  \
# 33  1992  Besiktas      30   23      7     0         58             20
#
#     goal_difference  points
# 33               38      76

# %%
sampi = pd.read_csv("tcl.csv", delimiter=";")
sampi["team"].value_counts()
# Out:
# Galatasaray    21
# Fenerbahce     19
# Besiktas       13
# Trabzonspor     6
# Bursaspor       1
# Name: team, dtype: int64

# %%
sampi = pd.read_csv("tcl.csv", delimiter=";")
a1 = sampi["points"]>70
a2 = sampi["team"] == "Galatasaray"
sampi[a1&a2]
# Out:
#     year         team  played  won  drawn  lost  goals_for  goals_against  \
# 29  1988  Galatasaray      38   27      9     2         86             35
# 38  1997  Galatasaray      34   25      7     2         90             30
# 39  1998  Galatasaray      34   23      6     5         86             43
# 40  1999  Galatasaray      34   23      9     2         85             30
# 41  2000  Galatasaray      34   24      7     3         77             23
# 43  2002  Galatasaray      34   24      6     4         75             31
# 47  2006  Galatasaray      34   26      5     3         82             34
# 49  2008  Galatasaray      34   24      7     3         64             23
# 53  2012  Galatasaray      34   23      8     3         69             24
# 54  2013  Galatasaray      34   21      8     5         66             35
# 56  2015  Galatasaray      34   24      5     5         60             35
# 59  2018  Galatasaray      34   24      3     7         75             33
#
# ...

# %%
sampi["kayip"] = sampi["lost"] + sampi["drawn"]
sampi
# Out:
#     year         team  played  won  drawn  lost  goals_for  goals_against  \
# 0   1959   Fenerbahce      16   13      2     1         33              8
# 1   1960     Besiktas      38   29      7     2         68             15
# 2   1961   Fenerbahce      38   26      9     3         81             29
# 3   1962  Galatasaray      38   23     11     4         52             18
# 4   1963  Galatasaray      22   14      7     1         54             14
# 5   1964   Fenerbahce      34   21     11     2         55             14
# 6   1965   Fenerbahce      30   18     11     1         52             13
# 7   1966     Besiktas      30   20      8     2         52             16
# 8   1967     Besiktas      32   16     13     3         44             15
# 9   1968   Fenerbahce      32   19     11     2         38             12
# 10  1969  Galatasaray      30   19      8     3         49             14
# 11  1970   Fenerbahce      30   17     10     3         31              6
# ...
