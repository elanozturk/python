# %% [markdown]
# <a href="https://colab.research.google.com/github/elanozturk/python/blob/main/Ders_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

sampi = pd.read_csv("tcl.csv", delimiter=";")
sampi.head(3)
# Out:
#    year        team  played  won  drawn  lost  goals_for  goals_against  \
# 0  1959  Fenerbahce      16   13      2     1         33              8
# 1  1960    Besiktas      38   29      7     2         68             15
# 2  1961  Fenerbahce      38   26      9     3         81             29
#
#    goal_difference  points
# 0               25      28
# 1               53      65
# 2               52      61

# %%
sampi["puanrevize"] = (sampi["won"])*3+sampi["drawn"]
sampi.head(3)
# Out:
#    year        team  played  won  drawn  lost  goals_for  goals_against  \
# 0  1959  Fenerbahce      16   13      2     1         33              8
# 1  1960    Besiktas      38   29      7     2         68             15
# 2  1961  Fenerbahce      38   26      9     3         81             29
#
#    goal_difference  points  puanrevize
# 0               25      28          41
# 1               53      65          94
# 2               52      61          87

# %%
filtre = sampi["points"]<80
sampi[filtre]
# Out:
#     year         team  played  won  drawn  lost  goals_for  goals_against  \
# 0   1959   Fenerbahce      16   13      2     1         33              8
# 1   1960     Besiktas      38   29      7     2         68             15
# 2   1961   Fenerbahce      38   26      9     3         81             29
# 3   1962  Galatasaray      38   23     11     4         52             18
# 4   1963  Galatasaray      22   14      7     1         54             14
# 5   1964   Fenerbahce      34   21     11     2         55             14
# 6   1965   Fenerbahce      30   18     11     1         52             13
# 7   1966     Besiktas      30   20      8     2         52             16
# 8   1967     Besiktas      32   16     13     3         44             15
# 9   1968   Fenerbahce      32   19     11     2         38             12
# 10  1969  Galatasaray      30   19      8     3         49             14
# 11  1970   Fenerbahce      30   17     10     3         31              6
# ...

# %%
filtre = sampi["points"]==sampi["puanrevize"]
sampi[filtre]
# Out:
#     year         team  played  won  drawn  lost  goals_for  goals_against  \
# 29  1988  Galatasaray      38   27      9     2         86             35
# 30  1989   Fenerbahce      36   29      6     1        103             27
# 31  1990     Besiktas      34   23      6     5         77             20
# 32  1991     Besiktas      30   20      9     1         63             24
# 33  1992     Besiktas      30   23      7     0         58             20
# 34  1993  Galatasaray      30   20      6     4         74             21
# 35  1994  Galatasaray      30   22      4     4         67             28
# 36  1995     Besiktas      34   24      7     3         80             26
# 37  1996   Fenerbahce      34   26      6     2         68             19
# 38  1997  Galatasaray      34   25      7     2         90             30
# 39  1998  Galatasaray      34   23      6     5         86             43
# 40  1999  Galatasaray      34   23      9     2         85             30
# ...

# %%
filtre = sampi["points"]==sampi["puanrevize"]
degisim = sampi[filtre]
degisim= degisim.sort_values(by="year")
#degisim = degisim.reset_index() #index resetleme
degisim = degisim.reset_index(drop=True) #index resetleme ve indexi sıfırlama
degisim["year"][0]
# Out:
# 1988

# %%
df = pd.read_csv("spotify.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3589 entries, 0 to 3588
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        3589 non-null   int64
#  1   Country           3589 non-null   object
#  2   Track Name        3583 non-null   object
#  3   Artist Name       3583 non-null   object
#  4   Album Name        3583 non-null   object
#  5   Popularity        3589 non-null   int64
#  6   Date              3589 non-null   object
#  7   Markets           3589 non-null   object
#  8   Danceability      3589 non-null   float64
#  9   Acousticness      3589 non-null   float64
#  10  duration          3589 non-null   int64
#  11  Energy            3589 non-null   float64
#  12  Instrumentalness  3589 non-null   float64
#  13  Key               3589 non-null   int64
#  14  Liveness          3589 non-null   float64
#  15  Loudness          3589 non-null   float64
# ...

# %%
filtre = df["Country"] == "TUR"
df[filtre]
# Out:
#       Unnamed: 0 Country                          Track Name  \
# 3339        3339     TUR                        Ateşe Düştüm
# 3340        3340     TUR                            Margiela
# 3341        3341     TUR                  Ağlama ben ağlarım
# 3342        3342     TUR                            Bertaraf
# 3343        3343     TUR                  aklına ben gelicem
# 3344        3344     TUR                            Kehribar
# 3345        3345     TUR                        BELLYDANCING
# 3346        3346     TUR                          Fark Ettim
# 3347        3347     TUR                          Can Dostum
# 3348        3348     TUR                        Lafı mı Olur
# 3349        3349     TUR                     Basit Numaralar
# 3350        3350     TUR                              Mesafe
# 3351        3351     TUR                                  B.
# 3352        3352     TUR                               Gitme
# ...

# %%
sayi =df["Country"].value_counts()
sayi = pd.DataFrame(sayi)
sayi
# Out:
#         Country
# Global       50
# MYS          50
# NZL          50
# NOR          50
# NGA          50
# ...         ...
# PHL          50
# EST          50
# USA          50
# ESP          50
# LUX          39
#
# [72 rows x 1 columns]

# %%
filtre = df["Country"] == "TUR"
tr = df[filtre]
tr = tr.sort_values(by="Popularity",ascending=False)
tr.head(3)
# Out:
#       Unnamed: 0 Country          Track Name  Artist Name          Album Name  \
# 3339        3339     TUR        Ateşe Düştüm   Mert Demir        Ateşe Düştüm
# 3343        3343     TUR  aklına ben gelicem        BLOK3  aklına ben gelicem
# 3349        3349     TUR     Basit Numaralar  Zerrin Özer     Basit Numaralar
#
#       Popularity        Date Markets  Danceability  Acousticness  ...  Energy  \
# 3339          84  2023-09-22      AR         0.657         0.835  ...   0.372
# 3343          82  2023-09-22      AR         0.277         0.148  ...   0.546
# 3349          81  2023-08-04      AR         0.775         0.506  ...   0.882
#
#       Instrumentalness  Key  Liveness  Loudness  Mode  Speechiness    Tempo  \
# 3339           0.01360    4    0.0981   -14.110     0       0.0476  188.011
# 3343           0.00000   10    0.2440   -10.798     0       0.0620  199.957
# 3349           0.00124    7    0.0808    -4.560     0       0.3060  154.949
#
#       TSignature  Positiveness
# ...

# %%
filtre = df["Country"] == "TUR"
tr = df[filtre]
tr = tr.sort_values(by=["Popularity", "Energy"],ascending=False)
tr.to_excel("trspotify.xlsx")

# %%
df["Artist Name"].value_counts()
# Out:
# Bad Bunny                        163
# Jung Kook                        147
# Taylor Swift                     118
# KAROL G                           62
# Doja Cat                          56
#                                 ...
# Jazzy                              1
# Richy Mitch & The Coal Miners      1
# The Cranberries                    1
# Hannah Laing                       1
# JustaTee                           1
# Name: Artist Name, Length: 1157, dtype: int64

# %%
arac = pd.read_html("https://tr.wikipedia.org/wiki/%C3%9Clkelere_g%C3%B6re_ara%C3%A7_say%C4%B1s%C4%B1_listesi")
arac[2]
# Out:
#        #                  Ülke  1000 kişiye düşen araç    Notlar
# 0      1            San Marino                    1263   2010[2]
# 1      2                Monako                     899   2008[2]
# 2      3                   ABD                     797   2010[2]
# 3      4           Lihtenştayn                     750   2010[2]
# 4      5               İzlanda                     745   2010[2]
# ..   ...                   ...                     ...       ...
# 186  177               Liberya                       3   2007[2]
# 187  177             Bangladeş                       3   2010[2]
# 188  177                   NaN                       3  2004[31]
# 189  182  São Tomé ve Príncipe                       2   2007[2]
# 190  182                  Togo                       2   2007[2]
#
# [191 rows x 4 columns]

# %%
link = ("https://tr.wikipedia.org/wiki/%C3%9Clkelere_g%C3%B6re_ara%C3%A7_say%C4%B1s%C4%B1_listesi")

arac = pd.read_html(link)[2]
arac.head(3)
# Out:
#    #        Ülke  1000 kişiye düşen araç   Notlar
# 0  1  San Marino                    1263  2010[2]
# 1  2      Monako                     899  2008[2]
# 2  3         ABD                     797  2010[2]

# %%
arac = arac[['Ülke','1000 kişiye düşen araç','Notlar']] #istediğimiz sütunları seçme

# %%
arac.columns=["Ülke","Adet","Yıl"] #Sütun ismi düzenleme

# %%
arac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ülke    190 non-null    object
#  1   Adet    191 non-null    int64
#  2   Yıl     191 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.6+ KB

# %%
arac["Yıl"].str.split("[")
#arac["Yıl"].str.split("[",expand=True)
#arac["Yıl"].str.split("[",expand=True)[0]
# Out:
# 0       [2010, 2]]
# 1       [2008, 2]]
# 2       [2010, 2]]
# 3       [2010, 2]]
# 4       [2010, 2]]
#           ...
# 186     [2007, 2]]
# 187     [2010, 2]]
# 188    [2004, 31]]
# 189     [2007, 2]]
# 190     [2007, 2]]
# Name: Yıl, Length: 191, dtype: object

# %%
arac["Yıl"].str.split("[",expand=True)
# Out:
#         0    1     2
# 0    2010   2]  None
# 1    2008   2]  None
# 2    2010   2]  None
# 3    2010   2]  None
# 4    2010   2]  None
# ..    ...  ...   ...
# 186  2007   2]  None
# 187  2010   2]  None
# 188  2004  31]  None
# 189  2007   2]  None
# 190  2007   2]  None
#
# [191 rows x 3 columns]

# %%
arac["Yıl"].str.split("[",expand=True)[0]
# Out:
# 0      2010
# 1      2008
# 2      2010
# 3      2010
# 4      2010
#        ...
# 186    2007
# 187    2010
# 188    2004
# 189    2007
# 190    2007
# Name: 0, Length: 191, dtype: object

# %%
arac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ülke    190 non-null    object
#  1   Adet    191 non-null    int64
#  2   Yıl     191 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.6+ KB

# %%
link = ("https://en.wikipedia.org/wiki/List_of_countries_by_vehicles_per_capita")

arac = pd.read_html(link)[0]
arac.head(3)
# Out:
#   Country or region  Motor vehicles per 1,000 people  Total     Year
# 0         Gibraltar                             1444  48641  2022[1]
# 1          Guernsey                             1365  86000  2014[2]
# 2        San Marino                             1300  44200  2022[3]

# %%
rank = pd.read_csv("rank.csv")
rank.head(1)
# Out:
#   Rank                                               Logo                Name  \
# 0    1  https://www.shanghairanking.com/_uni/logo/032b...  Harvard University
#
#                                                 Link                  Website  \
# 0  https://www.shanghairanking.com/institution/ha...   http://www.harvard.edu
#
#                                                 Flag         Country  \
# 0  https://www.shanghairanking.com/_pub/country-f...   United States
#
#           Region  Foundation_year  \
# 0  North America             1636
#
#                                              Address  \
# 0   Harvard University, Cambridge, Massachusetts ...
#
#                                                Intro  Total_Enrollment  \
# 0  Harvard University is devoted to excellence in...             41987
#
#    Total_International_Enrollment  UG_Enrollment  International_UG_Enrollment  \
# 0                            24.0          14467                         10.1
#
# ...

# %%
rank = pd.read_csv("rank.csv")
rank = rank[["Rank","Name","Country","Region","Foundation_year","Total_Enrollment"]]
#rank.head(3)
tr = rank[rank["Country"] == " Turkey"]
tr
# Out:
#          Rank                                  Name  Country Region  \
# 419   401-500                   Istanbul University   Turkey   Asia
# 679   601-700  University of Health Sciences Turkey   Turkey   Asia
# 720   701-800                  Hacettepe University   Turkey   Asia
# 726   701-800         Istanbul Technical University   Turkey   Asia
# 805   801-900                     Ankara University   Turkey   Asia
# 914  901-1000                        Ege University   Turkey   Asia
# 915  901-1000                    Erciyes University   Turkey   Asia
# 920  901-1000                       Gazi University   Turkey   Asia
#
#      Foundation_year  Total_Enrollment
# 419             1453             59250
# 679             1903             27010
# 720             1967             47035
# 726             1773             36581
# 805             1946             69737
# 914                0             46056
# 915             1978             39178
# ...

# %%
rank["Country"].unique()
# Out:
# array(['United States', 'United Kingdom', 'France', 'Switzerland',
#        'China', 'Canada', 'Japan', 'Denmark', 'Australia', 'Sweden',
#        'Netherlands', 'Germany', 'Israel', 'Singapore', 'Norway',
#        'Belgium', 'China-Hong Kong', 'South Korea', 'Saudi Arabia',
#        'Russia', 'Italy', 'Finland', 'Brazil', 'Austria', 'China-Taiwan',
#        'New Zealand', 'Ireland', 'Mexico', 'Spain', 'Argentina',
#        'South Africa', 'Portugal', 'Egypt', 'Czech Republic', 'India',
#        'Greece', 'Serbia', 'China-Macau', 'Turkey', 'Poland', 'Chile',
#        'Malaysia', 'Iran', 'Croatia', 'Thailand', 'Pakistan', 'Hungary',
#        'Qatar', 'Lithuania', 'Ethiopia', 'Iceland', 'Slovenia',
#        'Luxembourg', 'Lebanon', 'Cyprus', 'Estonia',
#        'United Arab Emirates', 'Jordan', 'Slovakia', 'Colombia', 'Ghana',
#        'Tunisia'], dtype=object)

# %%
rank["Country"] = rank["Country"].str.strip() #Baştaki ve sondaki boşlukları kaldırır(excel'deki kırp)

# %%
rank["Country"].unique()
# Out:
# array(['United States', 'United Kingdom', 'France', 'Switzerland',
#        'China', 'Canada', 'Japan', 'Denmark', 'Australia', 'Sweden',
#        'Netherlands', 'Germany', 'Israel', 'Singapore', 'Norway',
#        'Belgium', 'China-Hong Kong', 'South Korea', 'Saudi Arabia',
#        'Russia', 'Italy', 'Finland', 'Brazil', 'Austria', 'China-Taiwan',
#        'New Zealand', 'Ireland', 'Mexico', 'Spain', 'Argentina',
#        'South Africa', 'Portugal', 'Egypt', 'Czech Republic', 'India',
#        'Greece', 'Serbia', 'China-Macau', 'Turkey', 'Poland', 'Chile',
#        'Malaysia', 'Iran', 'Croatia', 'Thailand', 'Pakistan', 'Hungary',
#        'Qatar', 'Lithuania', 'Ethiopia', 'Iceland', 'Slovenia',
#        'Luxembourg', 'Lebanon', 'Cyprus', 'Estonia',
#        'United Arab Emirates', 'Jordan', 'Slovakia', 'Colombia', 'Ghana',
#        'Tunisia'], dtype=object)

# %%
df = pd.read_csv("dev.csv")
df.head(3)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9947 entries, 0 to 9946
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 9947 non-null   int64
#  1   Country              9947 non-null   object
#  2   Region               9947 non-null   object
#  3   SubRegion            9947 non-null   object
#  4   IntermRegion         4214 non-null   object
#  5   SurfAreaSqKm         9900 non-null   float64
#  6   PopDens              9297 non-null   float64
#  7   PopGrowth%           9929 non-null   float64
#  8   GDP                  8668 non-null   float64
#  9   GDPGrowth%           8424 non-null   float64
#  10  AdolFertRate         9947 non-null   float64
#  11  AgriValAdd%GDP       7496 non-null   float64
#  12  DomCredit%GDP        1185 non-null   float64
#  13  Exports%GDP          7434 non-null   float64
#  14  FertRate             9746 non-null   float64
# ...

# %%
df["perGDP"] = df["GDP"]/df["PopTotal"]
df.head(3)
df = df[["Year","Country","GDP","PopTotal","perGDP"]]
df.head(3)
# Out:
#    Year      Country           GDP    PopTotal       perGDP
# 0  1973  Afghanistan  1.733333e+09  11575305.0   149.744068
# 1  1973  Netherlands  7.184091e+10  13439322.0  5345.575444
# 2  1973       Poland           NaN  33357200.0          NaN

# %%
df[df["Country"]=="Turkiye"]
# Out:
#       Year  Country           GDP    PopTotal        perGDP
# 80    1973  Turkiye  2.572438e+10  38028236.0    676.454770
# 259   1974  Turkiye  3.559970e+10  38863420.0    916.020793
# 460   1975  Turkiye  4.463345e+10  39673590.0   1125.016660
# 651   1976  Turkiye  5.127987e+10  40500997.0   1266.138420
# 988   1977  Turkiye  5.867600e+10  41385656.0   1417.785883
# 1129  1978  Turkiye  6.514658e+10  42292206.0   1540.391989
# 1357  1979  Turkiye  8.939265e+10  43187476.0   2069.874318
# 1515  1980  Turkiye  6.878921e+10  44089069.0   1560.232859
# 1799  1981  Turkiye  7.104029e+10  44981877.0   1579.309069
# 1991  1982  Turkiye  6.454617e+10  45949991.0   1404.704674
# 2052  1983  Turkiye  6.167826e+10  47026425.0   1311.565940
# 2340  1984  Turkiye  5.999026e+10  48106764.0   1247.023473
# 2564  1985  Turkiye  6.723494e+10  49175673.0   1367.239804
# 2741  1986  Turkiye  7.572781e+10  50223885.0   1507.804772
# 2968  1987  Turkiye  8.716830e+10  51250152.0   1700.839796
# ...

# %%
df2021 = df[df["Year"]==2021]
df2021 = df2021.sort_values(by="perGDP",ascending=False)
df2021.head(20)
# Out:
#       Year         Country           GDP     PopTotal         perGDP
# 9858  2021   Liechtenstein  7.186429e+09      39039.0  184083.321374
# 9848  2021      Luxembourg  8.550624e+10     640064.0  133590.146976
# 9863  2021         Bermuda  7.127200e+09      63764.0  111774.669092
# 9770  2021         Ireland  5.041826e+11    5033165.0  100172.079253
# 9772  2021     Switzerland  8.006402e+11    8703405.0   91991.600458
# 9766  2021          Norway  4.902934e+11    5408320.0   90655.391023
# 9750  2021  Cayman Islands  6.028374e+09      68136.0   88475.600879
# 9764  2021       Singapore  4.237970e+11    5453566.0   77710.069957
# 9919  2021   United States  2.331508e+13  332031554.0   70219.472454
# 9785  2021   Faroe Islands  3.649879e+09      52889.0   69010.166201
# 9909  2021         Iceland  2.555264e+10     372520.0   68594.008104
# 9771  2021         Denmark  3.983033e+11    5856733.0   68007.756673
# 9753  2021           Qatar  1.796771e+11    2688235.0   66838.327641
# ...

# %%
df2021 = df2021.reset_index(drop=True)
filtre = df2021["Country"]=="Turkiye"
df2021[filtre]
# Out:
#     Year  Country           GDP    PopTotal       perGDP
# 80  2021  Turkiye  8.190345e+11  84775404.0  9661.227734
