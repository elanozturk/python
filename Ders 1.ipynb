# %%
print("Merhaba dünya!")
# Out:
# Merhaba dünya!

# %%
print(36)
# Out:
# 36

# %%
print("36")
# Out:
# 36

# %%
memleketim = "Aydın"
print(memleketim)
# Out:
# Aydın

# %%
uyarı = "Müşteri Hizmetlerine Başvurunuz!" #string -str -Metinsel
print(uyarı)
# Out:
# Müşteri Hizmetlerine Başvurunuz!

# %%
dolar = 28.64  # float - ondalık sayı
print(dolar)
# Out:
# 28.64

# %%
sayı = 1923 # integer- int

# %%
type(dolar)
# Out:
# float

# %%
type(1923)
# Out:
# int

# %%
type(memleketim)
# Out:
# str
